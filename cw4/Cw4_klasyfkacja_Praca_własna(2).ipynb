# %% [markdown]
# ##  Klasyfikacja z PyTorch
# Praca własna (lub w parach).
# Do wykonania są 2 zadania. Proszę przesłać na Moodla kody i zapis w html/Pdf w aktywności Zadanie 1

# %%
# Zaimportuj torch
import torch

# Konfiguracja kodu niezależnego od urządzenia


# Losowe ziarno
RANDOM_SEED = 42

# %% [markdown]
# ### Zadanie 1

# %% [markdown]
# ## 1. Utwórz zestaw danych klasyfikacji binarnej za pomocą funkcji Scikit-Learn [`make_moons()`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html).
#   Dla zachowania spójności, zbiór danych powinien mieć 1000 próbek i random_state=42.
# Przekształć dane w tensory PyTorch.
# Podziel dane na zestawy treningowe i testowe za pomocą train_test_split z 80% danych uczących i 20% testowych.

# %%
# Utwórz zbiór danych za pomocą funkcji make_moons() Scikit-Learn.
from sklearn.datasets import make_moons
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Utwórz zbiór danych za pomocą funkcji make_moons() Scikit-Learn.
# ----> 2 from sklearn.datasets import make_moons
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Przekształć dane na DataFrame
import pandas as pd

# %%
# Wizualizacja danych na wykresie rozrzutu
import matplotlib.pyplot as plt

# %%
# Przekształcenie danych w tensory typu dtype float


# Podziel dane na zestawy treningowe i testowe (80% trening, 20% test).
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 2. Zbuduj model poprzez podklasę `nn.Module`, który zawiera nieliniowe funkcje aktywacji i jest w stanie dopasować się do danych utworzonych w punkcie 1.
#   * Możesz użyć dowolnej kombinacji warstw PyTorch (liniowych i nieliniowych).

# %%
import torch
from torch import nn

# Dziedziczenie z nn.Module w celu stworzenia modelu zdolnego do dopasowania danych Moon
class MoonModelV0(nn.Module):
    ## Twój kod ##

    def forward(self, x):
        ## Twój kod ##
        return

# Instancja modelu
## Twój kod ##

# %% [markdown]
# ## 3. Skonfiguruj funkcję straty zgodną z klasyfikacją binarną i optymalizator do wykorzystania podczas uczenia modelu zbudowanego w punkcie 2.

# %%
# Konfiguracja funkcji straty

# Konfiguracja optymalizatora do optymalizacji parametrów modelu

# %% [markdown]
# ## 4. Utwórz pętlę uczącą i testową, aby dopasować model utworzony w punkcie 2 do danych utworzonych w punkcie 1.
#   * Propagacje w przód. Patrzymy, co wychodzi w postaci logitów, prawdopodobieństw predykcji i etykiet.
#   * Aby zmierzyć dokładność modelu, można utworzyć własną funkcję dokładności lub użyć funkcji dokładności w [TorchMetrics](https://torchmetrics.readthedocs.io/en/latest/).
#   * Ucz model wystarczająco długo, aby osiągnął dokładność ponad 96%.
#   * Pętla ucząca powinna co 10 epok generować postępy w zakresie strat i dokładności zestawu treningowego i testowego modelu.

# %%
# Wynik modelu

# logity (wynik modelu)
print("Logits:")
## Twój kod ##

# Prawdopodobieństwa
print("Pred probs:")
## Twój kod ##

# Etykiety
print("Pred labels:")
## Kod ##

# %%
# Obliczmy dokładność, korzystając z dokładności TorchMetrics
# !pip -q install torchmetrics # Colab nie ma wbudowanego torchmetrics
from torchmetrics import Accuracy

## Usuń komentarz z tego kodu, aby użyć funkcji Dokładność
# acc_fn = Accuracy(task="multiclass", num_classes=2).to(device) # Wysyłanie dokładności do urządzenia
# acc_fn

# %%
## Usuń komentarz z tego kodu
# torch.manual_seed(RANDOM_SEED)

# Zadeklaruj liczbę epok


# Wysyłanie danych do urządzenia


# Pętla ucząca przez dane
# for epoch in range(epochs):
  ### Uczenie


  # 1. Propagacja do przodu (wynikiem jest logit)

  # Przekształcenie logitów w prawdopodobieństwa predykcji


  # Przekształć prawdopodobieństwa predykcji w etykiety predykcji


  # 2. Obliczenie straty
  # loss = loss_fn(y_logits, y_train) # loss = compare model raw outputs to desired model outputs

  # Obliczenie dokładności
  # acc = acc_fn(y_pred, y_train.int()) # funkcja dokładności musi porównywać przewidywane etykiety (nie logity) z rzeczywistymi etykietami

  # 3. Zerowanie gradientów


  # 4. Propagacja wsteczna (Loss backward)) - https://brilliant.org/wiki/backpropagation/#:~:text=Backpropagation%2C%20short%20for%20%22backward%20propagation,to%20the%20neural%20network's%20weights.

  # 5. Krok optymalizacyjny (gradient descent) - https://towardsdatascience.com/gradient-descent-algorithm-a-deep-dive-cf04e8115f21#:~:text=Gradient%20descent%20(GD)%20is%20an,e.g.%20in%20a%20linear%20regression)


  ### Testowanie
  # model_0.eval()
  # z torch.inference_mode():
    # 1. Przejście do przodu (aby uzyskać logity)

    # Przekształć logity testowe w etykiety predykcji


    # 2. Oblicz stratę testową/acc


  # Wydrukuj, co dzieje się co 100 epok
  # if epoch % 100 == 0:

# %% [markdown]
# ## 5. Wykonaj prognozy za pomocą wytrenowanego modelu i wykreśl je za pomocą funkcji `plot_decision_boundary()`

# %%
# Wykreśl przewidywania modelu
import numpy as np

def plot_decision_boundary(model, X, y):

    # Umieść wszystko w CPU (działa lepiej z NumPy + Matplotlib)
    model.to("cpu")
    X, y = X.to("cpu"), y.to("cpu")


    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 101),
                         np.linspace(y_min, y_max, 101))

    # Cechy
    X_to_pred_on = torch.from_numpy(np.column_stack((xx.ravel(), yy.ravel()))).float()

    # Przewidywania
    model.eval()
    with torch.inference_mode():
        y_logits = model(X_to_pred_on)

    # Test wieloklasowy lub binarny i dostosowanie logitów do etykiet predykcji
    if len(torch.unique(y)) > 2:
        y_pred = torch.softmax(y_logits, dim=1).argmax(dim=1) # wieloklasowa
    else:
        y_pred = torch.round(torch.sigmoid(y_logits)) # binarna

    # Przekształć
    y_pred = y_pred.reshape(xx.shape).detach().numpy()
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())

# %%
# Wyznaczanie granic decyzji dla zestawów treningowych i testowych

# %% [markdown]
# ## 6. Dokonaj oceny modelu wyznaczając macierz pomyłek oraz miary diagnostyczne

# %% [markdown]
# ### Zadanie 2

# %% [markdown]
# Jeśli zostało Ci trochę czasu i masz ochotę trochę się pobawić, możesz zbudowac model dla spiral:
# [Dane z CS231n](https://cs231n.github.io/neural-networks-case-study/)
